# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from collections import defaultdict

def load_and_clean_data(filepath):
   try:
     df = pd.read_csv(filepath)
     df.columns = ['Date', 'Rainfall (mm)', 'Temperature (C)', 'Humidity', 'Wind Speed (km/h)', 'Weather Condition']
     df_cleaned = df.dropna()
     return df_cleaned
   except Exception as e:
     print("Failed to load the dataset. Please check the file path and format. Error: {e}")
     return None

def add_condition_column(df): conditions = []
for _, row in df.iterrows():
      if row['Rainfall (mm)'] > 5:
          conditions.append('Rainy')
      elif row['Temperature (C)'] > 25:
          conditions.append('Sunny')
      elif row['Humidity'] > 80:
          conditions.append('Humid')
      else:
          conditions.append('Normal')
    df ['condition'] = conditions
    return df

def construct_hash_table (weather_data):
    hash_table = defaultdict(list)
    for date, condition in weather_data:
        hash_table[condition].append(date)
    return hash_table # 0(1)

def search_weather_condition (hash_table, condition):
    return hash_table.get(condition, [])
            print("Dates with the specified weather condition:")
            for date in dates:
                print(date)
            else:
                print("No dates found with the specified weather condition.")

def preprocess_data_clustering (df):
    features = ['Rainfall (mm)', 'Temperature (C)', 'Humidity', 'Wind Speed (km/h)']
    df features df [features]
    scaler = StandardScaler()
    df_features_scaled = scaler.fit_transform (df_features)
    return df_features_scaled

def perform clustering (df, df_features_scaled, n_clusters=3):
    kmeans KMeans (n_clusters=n_clusters, random_state=42)
    df ['cluster'] = kmeans.fit_predict (df_features_scaled)
    return kmeans

def visualize_clusters (df, kmeans):
    plt.figure(figsize=(10, 6))
    plt.scatter(df ['Temperature (C)'], df ['Humidity'], c=df['cluster'], cmap='viridis')
    plt.xlabel('Temperature (C)')
    plt.title('Weather Clusters')
    plt.ylabel('Humidity')
    plt.colorbar (label='Cluster')
    plt.show()

def preprocess_data_regression (df):
    df['Date'] = pd.to_datetime (df ['Date'], errors='coerce')
    df = df.dropna (subset=['Date'])
    df ['day_of_year'] = df ['Date'].dt.dayofyear
    df['year'] = df ['Date'].dt.year
    features = ['day_of_year', 'year', 'Rainfall (mm)', 'Humidity', 'Wind Speed (km/h)']
    target 'Temperature (C)'
    X = df [features]
    y=df[target]
    return X, y

def train_model(x, y):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
    model Decision TreeRegressor (random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean squared_error(y_test, y_pred)
    print("Mean Squared Error: {mse}")
    return model

def predict_future_weather (model, future_date):
    future_date = pd.to_datetime (future_date)
    day_of_year = future_date.dayofyear
    year = future_date.year
    future_input = pd.DataFrame({
        'day_of_year' [day_of_year],
        'year': [year],
        'Rainfall (mm): [0],
        'Humidity: [0],
        'Wind Speed (km/h): [0]
        })
    future_temperature = model.predict(future_input)
    return future_temperature[0]

def main():
    while True:
        print("\nChoose an option:")
        print("1. Search for specific weather conditions")
        print("2. Train a Decision Tree Regressor and predict future weather")
        print("3. Display cluster centroids")
        print("4. Visualize weather clusters")
        print("5. Exit")
        choice = input("\nEnter your choice: ")
        if choice == '1':
            df = load_and_clean_data('weather.csv')
            if df is not None:
                df = add_condition_column(df)
                weather_data=df[['Date', 'condition']].values
                hash_table = construct_hash_table(weather_data)
                condition = input ("Enter the weather condition to search for (Rainy, Sunny, Humid, Normal): ").strip().capitalize()
                dates = search_weather_condition (hash_table, condition)
                output_results(dates)
        elif choice == '2':
            df = load_and_clean_data('weather.csv')
            if df is not None:
                X, y = preprocess_data_regression (df)
                model train_model(x, y)
                while True:
                future_date = input("\nEnter a future date (YYYY-MM-DD) to predict the temperature (or type 'back' to return to main menu): ")
                if future_date. lower() == 'back':
                   break
                try:
                    predicted_temp = predict_future_weather (model, future_date)
                    print("Predicted temperature for {future_date): {predicted_temp: .2f}°C")
                except Exception as e:
                    print("Error predicting temperature: {e}")
        elif choice == '3' or choice == '4':
            df = load_and_clean_data('weather.csv')
            if df is not None:
            df_features_scaled = preprocess_data_clustering (df)
            kmeans = perform_clustering (df, df_features_scaled)
            if choice == '3':
                print("\nCluster centroids:")
                print(kmeans.cluster_centers_)
            elif choice == '4':
                visualize_clusters (df, kmeans)
        elif choice == '5':
            print("\nExiting the program.")
            break
        else:
        print("Invalid choice. Please select a valid option.")

if __name__ == "__main__":
main()
# Out:
#   File "<tokenize>", line 30
#     df ['condition'] = conditions
#     ^
# IndentationError: unindent does not match any outer indentation level
